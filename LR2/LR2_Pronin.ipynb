# %%
import pyspark
import os

from datetime import datetime
from pyspark.sql.functions import col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, DateType
from pyspark import SparkContext, SparkConf

# %%
#для чтения xml
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.12:0.13.0 pyspark-shell'

# %%
sc = SparkSession.builder.appName("LR2").master("yarn").getOrCreate()

# %%
# !hadoop fs -put ~/ /user
# Out:
# put: `/user/zse4vfr/.bash_history': File exists
# put: `/user/zse4vfr/.bash_logout': File exists
# put: `/user/zse4vfr/.bashrc': File exists
# put: `/user/zse4vfr/.cache/motd.legal-displayed': File exists
# put: `/user/zse4vfr/.ipython/profile_default/history.sqlite': File exists
# put: `/user/zse4vfr/.ipython/profile_default/startup/README': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.databricks/spark-xml_2.12/ivy-0.13.0.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.databricks/spark-xml_2.12/ivy-0.13.0.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.databricks/spark-xml_2.12/ivydata-0.13.0.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.databricks/spark-xml_2.12/jars/spark-xml_2.12-0.13.0.jar': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind/jaxb-bom-ext/ivy-2.3.4.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind/jaxb-bom-ext/ivy-2.3.4.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind/jaxb-bom-ext/ivydata-2.3.4.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-parent/ivy-2.3.4.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-parent/ivy-2.3.4.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-parent/ivydata-2.3.4.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-txw-parent/ivy-2.3.4.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-txw-parent/ivy-2.3.4.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/com.sun.xml.bind.mvn/jaxb-txw-parent/ivydata-2.3.4.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/commons-io/commons-io/ivy-2.8.0.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/commons-io/commons-io/ivy-2.8.0.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/commons-io/commons-io/ivydata-2.8.0.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/commons-io/commons-io/jars/commons-io-2.8.0.jar': File exists
# put: `/user/zse4vfr/.ivy2/cache/ivy-report.css': File exists
# put: `/user/zse4vfr/.ivy2/cache/ivy-report.xsl': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivy-21.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivy-21.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivy-23.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivy-23.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivydata-21.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache/apache/ivydata-23.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.commons/commons-parent/ivy-52.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.commons/commons-parent/ivy-52.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.commons/commons-parent/ivydata-52.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema/ivy-2.2.5.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema/ivy-2.2.5.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema/ivydata-2.2.5.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema-core/bundles/xmlschema-core-2.2.5.jar': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema-core/ivy-2.2.5.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema-core/ivy-2.2.5.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.apache.ws.xmlschema/xmlschema-core/ivydata-2.2.5.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.eclipse.ee4j/project/ivy-1.0.7.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.eclipse.ee4j/project/ivy-1.0.7.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.eclipse.ee4j/project/ivydata-1.0.7.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/jaxb-bom/ivy-2.3.4.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/jaxb-bom/ivy-2.3.4.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/jaxb-bom/ivydata-2.3.4.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/txw2/ivy-2.3.4.xml': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/txw2/ivy-2.3.4.xml.original': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/txw2/ivydata-2.3.4.properties': File exists
# put: `/user/zse4vfr/.ivy2/cache/org.glassfish.jaxb/txw2/jars/txw2-2.3.4.jar': File exists
# put: `/user/zse4vfr/.ivy2/jars/com.databricks_spark-xml_2.12-0.13.0.jar': File exists
# put: `/user/zse4vfr/.ivy2/jars/commons-io_commons-io-2.8.0.jar': File exists
# put: `/user/zse4vfr/.ivy2/jars/org.apache.ws.xmlschema_xmlschema-core-2.2.5.jar': File exists
# put: `/user/zse4vfr/.ivy2/jars/org.glassfish.jaxb_txw2-2.3.4.jar': File exists
# put: `/user/zse4vfr/.jupyter/lab/user-settings/@jupyterlab/extensionmanager-extension/plugin.jupyterlab-settings': File exists
# put: `/user/zse4vfr/.jupyter/lab/user-settings/@jupyterlab/filebrowser-extension/browser.jupyterlab-settings': File exists
# put: `/user/zse4vfr/.jupyter/lab/workspaces/auto-s-f09b.jupyterlab-workspace': File exists
# put: `/user/zse4vfr/.jupyter/lab/workspaces/default-37a8.jupyterlab-workspace': File exists
# put: `/user/zse4vfr/.jupyter/migrated': File exists
# put: `/user/zse4vfr/.local/share/jupyter/nbsignatures.db': File exists
# put: `/user/zse4vfr/.local/share/jupyter/notebook_secret': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/kernel-901a90d4-613f-4ecf-9731-5acfd64f83ee.json': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/kernel-98b37b50-b0e2-4cf5-9644-43d3583bec17.json': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/kernel-bae2d9f3-dfd7-4198-8fb3-53f6fe09ef06.json': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/nbserver-5134-open.html': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/nbserver-5134.json': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/nbserver-7776-open.html': File exists
# put: `/user/zse4vfr/.local/share/jupyter/runtime/nbserver-7776.json': File exists
# put: `/user/zse4vfr/.profile': File exists
# put: `/user/zse4vfr/.ssh/authorized_keys': File exists
# put: `/user/zse4vfr/.ssh/config': File exists
# put: `/user/zse4vfr/.ssh/known_hosts': File exists
# put: `/user/zse4vfr/.ssh/zse4vfr_ecdsa': File exists
# put: `/user/zse4vfr/.ssh/zse4vfr_ecdsa.pub': File exists
# put: `/user/zse4vfr/LR1/LR1_Pronin.ipynb': File exists
# put: `/user/zse4vfr/LR1/station.csv': File exists
# put: `/user/zse4vfr/LR1/trip.csv': File exists
# put: `/user/zse4vfr/LR2/.ipynb_checkpoints/LR2_Pronin-checkpoint.ipynb': File exists
# put: `/user/zse4vfr/LR2/LR2_Pronin.ipynb': File exists
# put: `/user/zse4vfr/LR2/posts_sample.xml': File exists
# put: `/user/zse4vfr/LR2/programming-languages.csv': File exists

# %%
prog_lang = sc.read.csv("LR2/programming-languages.csv")
posts_sample = sc.read.format("xml").options(rowTag="row").load('LR2/posts_sample.xml')

# %%
prog_lang_list = [str(x[0]) for x in prog_lang.collect()]
prog_lang_list[:7]
# Out:
# ['name', 'A# .NET', 'A# (Axiom)', 'A-0 System', 'A+', 'A++', 'ABAP']

# %%
def find_language(x):
    tag = None
    for language in prog_lang_list:
        if "<" + language.lower() + ">" in x._Tags.lower():
            tag = language
            break
    if tag is None:
        return None
    return (x._Id, tag)

def is_year_date(x, year):
    start = datetime(year=year, month=1, day=1)
    end = datetime(year=year, month=12, day=31)
    return x._CreationDate >= start and x._CreationDate <= end

# %%
pl_by_year = {}

for year in range(2010, 2020):
    pl_by_year[year] = posts_sample.rdd \
        .filter(lambda x: x._Tags is not None and is_year_date(x, year)) \
        .map(find_language) \
        .filter(lambda x: x is not None) \
        .keyBy(lambda x: x[1]) \
        .aggregateByKey(0, lambda x, y: x + 1, lambda x, y: x + y) \
        .sortBy(lambda x: x[1], ascending=False) \
        .toDF()

    pl_by_year[year] = pl_by_year[year] \
                        .select(col("_1").alias("PL"), col("_2").alias(f"Mentioned_in_{year}")) \
                        .limit(10)

    pl_by_year[year].show()
# Out:
# +-----------+-----------------+
# |         PL|Mentioned_in_2010|
# +-----------+-----------------+
# |       Java|               52|
# | JavaScript|               44|
# |        PHP|               42|
# |     Python|               25|
# |Objective-C|               22|
# |          C|               20|
# |       Ruby|               11|
# |     Delphi|                7|
# |AppleScript|                3|
# |          R|                3|
# +-----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2011|
# +-----------+-----------------+
# |        PHP|               97|
# |       Java|               92|
# | JavaScript|               82|
# |     Python|               35|
# |Objective-C|               33|
# |          C|               24|
# |       Ruby|               17|
# |       Perl|                8|
# |     Delphi|                8|
# |       Bash|                7|
# +-----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2012|
# +-----------+-----------------+
# |        PHP|              136|
# | JavaScript|              129|
# |       Java|              124|
# |     Python|               65|
# |Objective-C|               45|
# |          C|               27|
# |       Ruby|               25|
# |       Bash|                9|
# |          R|                9|
# |     MATLAB|                6|
# +-----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2013|
# +-----------+-----------------+
# | JavaScript|              196|
# |       Java|              191|
# |        PHP|              173|
# |     Python|               87|
# |Objective-C|               40|
# |          C|               36|
# |       Ruby|               30|
# |          R|               25|
# |       Bash|               11|
# |      Scala|               10|
# +-----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2014|
# +-----------+-----------------+
# | JavaScript|              235|
# |       Java|              228|
# |        PHP|              154|
# |     Python|              103|
# |          C|               52|
# |Objective-C|               49|
# |          R|               28|
# |       Ruby|               20|
# |     MATLAB|               16|
# |       Bash|               13|
# +-----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2015|
# +-----------+-----------------+
# | JavaScript|              268|
# |       Java|              208|
# |        PHP|              147|
# |     Python|              119|
# |          R|               43|
# |          C|               38|
# |Objective-C|               30|
# |       Ruby|               20|
# |     MATLAB|               16|
# |      Scala|               13|
# +-----------+-----------------+
#
# +----------+-----------------+
# |        PL|Mentioned_in_2016|
# +----------+-----------------+
# |JavaScript|              271|
# |      Java|              178|
# |    Python|              140|
# |       PHP|              126|
# |         R|               50|
# |         C|               32|
# |      Ruby|               21|
# |      Bash|               16|
# |     Scala|               16|
# |    MATLAB|               15|
# +----------+-----------------+
#
# +-----------+-----------------+
# |         PL|Mentioned_in_2017|
# +-----------+-----------------+
# | JavaScript|              244|
# |       Java|              204|
# |     Python|              185|
# |        PHP|              122|
# |          R|               53|
# |          C|               24|
# |Objective-C|               19|
# |       Ruby|               16|
# | PowerShell|               14|
# | TypeScript|               14|
# +-----------+-----------------+
#
# +----------+-----------------+
# |        PL|Mentioned_in_2018|
# +----------+-----------------+
# |    Python|              214|
# |JavaScript|              194|
# |      Java|              145|
# |       PHP|               99|
# |         R|               63|
# |         C|               24|
# |     Scala|               22|
# |TypeScript|               21|
# |PowerShell|               13|
# |      Bash|               12|
# +----------+-----------------+
#
# +----------+-----------------+
# |        PL|Mentioned_in_2019|
# +----------+-----------------+
# |    Python|              162|
# |JavaScript|              131|
# |      Java|               95|
# |       PHP|               59|
# |         R|               36|
# |         C|               14|
# |    MATLAB|                9|
# |        Go|                9|
# |    Kotlin|                9|
# |      Dart|                9|
# +----------+-----------------+

# %%
for i in pl_by_year.keys():
    pl_by_year[i].write.format("parquet").save(f"LR2/results/pl_by_{i}")

# %%
# !hadoop fs -get /user/zse4vfr/LR2/results ~/results
# Out:
# get: `/home/zse4vfr/F:/ScientificWork/results': No such file or directory

# %%
sc.stop()
